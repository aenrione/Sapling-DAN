# %% [markdown]
# # Propuesta Proyecto RecSys 2025
#
# Integrantes: Felipe Abarca, Nicolas Estevez, Alfredo Enrione

# %% [markdown]
# ## Setup Datos

# %%
from IPython.display import clear_output
# !pip install datasets
clear_output()
NUM_SAMPLES = 10000

# %%
from datasets import load_dataset, load_from_disk
dataset_name = "amazon_reviews_books"
try:
    reviews = load_from_disk(dataset_name)
except:
    reviews = load_dataset("McAuley-Lab/Amazon-Reviews-2023", "raw_review_Books", trust_remote_code=True)
    reviews.save_to_disk(dataset_name)
    reviews.cleanup_cache_files()

#try:
#  metadata = load_from_disk("metadata")
#except:
#  metadata = load_dataset("McAuley-Lab/Amazon-Reviews-2023", "raw_meta_Books", trust_remote_code=True)
#  metadata.save_to_disk("metadata")
#  metadata.cleanup_cache_files()
# Out:
# Loading dataset from disk:   0%|          | 0/33 [00:00<?, ?it/s]

# %% [markdown]
# ## Corriendo el modelo

# %%
import warnings
from loader import Loader
from utils_lae import run_experiments, sensitivity_analysis_combine
warnings.filterwarnings("ignore")

config = {
    'reg_p': 10,
    'alpha': 0.2,
    'beta': 0.2,
    'drop_p': 0.2,
    'xi': 0.0,
    'eta': 10
}
gamma = 0.8 # Paper Sapling Similarity \gamma = 0.8
alpha = 0.5 # Hacer análisis de sensibilidad con alpha
k_values = [10, 20]

# %% [markdown]
# ## Amazon Books Reviews

# %%
loader = Loader(number_of_samples=NUM_SAMPLES) # By default, it uses the amazon_reviews_books dataset
results_books = run_experiments(loader, config, gamma, alpha, k_values)
sensitivity_books = sensitivity_analysis_combine(loader, config, gamma, k_values)
# Out:
# Loading dataset from disk:   0%|          | 0/33 [00:00<?, ?it/s]
# Metrics @ 10 for model pipeline (normalization=LAE): {'precision@10': 0.0, 'recall@10': 0.0, 'ndcg@10': 0.0}
# Metrics @ 20 for model pipeline (normalization=LAE): {'precision@20': 0.0005000000000000001, 'recall@20': 0.0021234939759036146, 'ndcg@20': 0.0007947691394405591}
# Metrics @ 10 for model combine (normalization=LAE): {'precision@10': 0.0, 'recall@10': 0.0, 'ndcg@10': 0.0}
# Metrics @ 20 for model combine (normalization=LAE): {'precision@20': 0.0, 'recall@20': 0.0, 'ndcg@20': 0.0}
# Metrics @ 10 for model regularization (normalization=LAE): {'precision@10': 0.0, 'recall@10': 0.0, 'ndcg@10': 0.0}
# Metrics @ 20 for model regularization (normalization=LAE): {'precision@20': 0.0003333333333333334, 'recall@20': 0.0033666666666666667, 'ndcg@20': 0.0009447916379490451}
# Metrics @ 10 for model dan (normalization=LAE): {'precision@10': 0.0006666666666666668, 'recall@10': 1.2970168612191959e-05, 'ndcg@10': 0.0006943122193677726}
# Metrics @ 20 for model dan (normalization=LAE): {'precision@20': 0.0003333333333333334, 'recall@20': 1.2970168612191959e-05, 'ndcg@20': 0.0004480864360167173}
# Metrics @ 10 for model sapling (normalization=None): {'precision@10': 0.0003333333333333334, 'recall@10': 0.0033333333333333335, 'ndcg@10': 0.0009635494210596263}
# Metrics @ 20 for model sapling (normalization=None): {'precision@20': 0.0003333333333333334, 'recall@20': 0.00375, 'ndcg@20': 0.0011850003653028802}
# Metrics @ 10 for model dan (normalization=LAE): {'precision@10': 0.0006666666666666668, 'recall@10': 1.2970168612191959e-05, 'ndcg@10': 0.0006943122193677726}
# Metrics @ 20 for model dan (normalization=LAE): {'precision@20': 0.0003333333333333334, 'recall@20': 1.2970168612191959e-05, 'ndcg@20': 0.0004480864360167173}
# Metrics @ 10 for model combine (alpha=0.0): {'precision@10': 0.0006666666666666668, 'recall@10': 1.2970168612191959e-05, 'ndcg@10': 0.0006943122193677726}
# Metrics @ 20 for model combine (alpha=0.0): {'precision@20': 0.0003333333333333334, 'recall@20': 1.2970168612191959e-05, 'ndcg@20': 0.0004480864360167173}
# Metrics @ 10 for model combine (alpha=0.1): {'precision@10': 0.0003333333333333334, 'recall@10': 6.485084306095979e-06, 'ndcg@10': 0.00031596121456516925}
# Metrics @ 20 for model combine (alpha=0.1): {'precision@20': 0.0001666666666666667, 'recall@20': 6.485084306095979e-06, 'ndcg@20': 0.0002039110512601062}
# Metrics @ 10 for model combine (alpha=0.2): {'precision@10': 0.0, 'recall@10': 0.0, 'ndcg@10': 0.0}
# Metrics @ 20 for model combine (alpha=0.2): {'precision@20': 0.0, 'recall@20': 0.0, 'ndcg@20': 0.0}
# Metrics @ 10 for model combine (alpha=0.30000000000000004): {'precision@10': 0.0, 'recall@10': 0.0, 'ndcg@10': 0.0}
# Metrics @ 20 for model combine (alpha=0.30000000000000004): {'precision@20': 0.0, 'recall@20': 0.0, 'ndcg@20': 0.0}
# Metrics @ 10 for model combine (alpha=0.4): {'precision@10': 0.0, 'recall@10': 0.0, 'ndcg@10': 0.0}
# Metrics @ 20 for model combine (alpha=0.4): {'precision@20': 0.0, 'recall@20': 0.0, 'ndcg@20': 0.0}
# Metrics @ 10 for model combine (alpha=0.5): {'precision@10': 0.0, 'recall@10': 0.0, 'ndcg@10': 0.0}
# Metrics @ 20 for model combine (alpha=0.5): {'precision@20': 0.0, 'recall@20': 0.0, 'ndcg@20': 0.0}
# Metrics @ 10 for model combine (alpha=0.6000000000000001): {'precision@10': 0.0, 'recall@10': 0.0, 'ndcg@10': 0.0}
# Metrics @ 20 for model combine (alpha=0.6000000000000001): {'precision@20': 0.0, 'recall@20': 0.0, 'ndcg@20': 0.0}
# Metrics @ 10 for model combine (alpha=0.7000000000000001): {'precision@10': 0.0, 'recall@10': 0.0, 'ndcg@10': 0.0}
# Metrics @ 20 for model combine (alpha=0.7000000000000001): {'precision@20': 0.0005, 'recall@20': 0.00013333333333333334, 'ndcg@20': 0.00034083545446521524}
# Metrics @ 10 for model combine (alpha=0.8): {'precision@10': 0.0, 'recall@10': 0.0, 'ndcg@10': 0.0}
# Metrics @ 20 for model combine (alpha=0.8): {'precision@20': 0.0, 'recall@20': 0.0, 'ndcg@20': 0.0}
# Metrics @ 10 for model combine (alpha=0.9): {'precision@10': 0.0, 'recall@10': 0.0, 'ndcg@10': 0.0}
# Metrics @ 20 for model combine (alpha=0.9): {'precision@20': 0.0, 'recall@20': 0.0, 'ndcg@20': 0.0}
# Metrics @ 10 for model combine (alpha=1.0): {'precision@10': 0.0003333333333333334, 'recall@10': 5.747126436781609e-05, 'ndcg@10': 0.0002613275632622511}
# Metrics @ 20 for model combine (alpha=1.0): {'precision@20': 0.0001666666666666667, 'recall@20': 5.747126436781609e-05, 'ndcg@20': 0.00016865227658205686}

# %% [markdown]
# ## Otros Dataset

# %% [markdown]
# ### Amazon - Product

# %%
from datasets import load_dataset, load_from_disk
dataset_name = "amazon_products"
try:
  products = load_from_disk(dataset_name)
except:
  products = load_dataset("minhth2nh/amazon_product_review_283K", trust_remote_code=True)
  products.save_to_disk(dataset_name)
  products.cleanup_cache_files()

  print(products)

# %%
loader_products = Loader(dataset_name=dataset_name, subset_name="train", number_of_samples=NUM_SAMPLES, user_id_column="user_id")
results_products = run_experiments(loader_products, config, gamma, alpha, k_values)
sensitivity_products = sensitivity_analysis_combine(loader_products, config, gamma, k_values)
# Out:
# Metrics @ 10 for model pipeline (normalization=LAE): {'precision@10': 0.0, 'recall@10': 0.0, 'ndcg@10': 0.0}
# Metrics @ 20 for model pipeline (normalization=LAE): {'precision@20': 6.666666666666667e-05, 'recall@20': 0.0013333333333333333, 'ndcg@20': 0.0003138785511555177}
# Metrics @ 10 for model combine (normalization=LAE): {'precision@10': 0.00013333333333333334, 'recall@10': 0.0002666666666666667, 'ndcg@10': 0.00014265750982301838}
# Metrics @ 20 for model combine (normalization=LAE): {'precision@20': 0.00013333333333333334, 'recall@20': 0.0007111111111111111, 'ndcg@20': 0.00029908375183060386}
# Metrics @ 10 for model regularization (normalization=LAE): {'precision@10': 0.0, 'recall@10': 0.0, 'ndcg@10': 0.0}
# Metrics @ 20 for model regularization (normalization=LAE): {'precision@20': 0.00020000000000000004, 'recall@20': 0.0029333333333333334, 'ndcg@20': 0.0008119442742992434}
# Metrics @ 10 for model dan (normalization=LAE): {'precision@10': 0.00013333333333333334, 'recall@10': 0.0002666666666666667, 'ndcg@10': 0.00013612986016388218}
# Metrics @ 20 for model dan (normalization=LAE): {'precision@20': 6.666666666666667e-05, 'recall@20': 0.0002666666666666667, 'ndcg@20': 0.00013612986016388218}
# Metrics @ 10 for model sapling (normalization=None): {'precision@10': 0.0018666666666666666, 'recall@10': 0.01671111111111111, 'ndcg@10': 0.006662106464697542}
# Metrics @ 20 for model sapling (normalization=None): {'precision@20': 0.0012666666666666666, 'recall@20': 0.023377777777777775, 'ndcg@20': 0.008294222736273298}
# Metrics @ 10 for model dan (normalization=LAE): {'precision@10': 0.00013333333333333334, 'recall@10': 0.0002666666666666667, 'ndcg@10': 0.00013612986016388218}
# Metrics @ 20 for model dan (normalization=LAE): {'precision@20': 6.666666666666667e-05, 'recall@20': 0.0002666666666666667, 'ndcg@20': 0.00013612986016388218}
# Metrics @ 10 for model combine (alpha=0.0): {'precision@10': 0.00013333333333333334, 'recall@10': 0.0002666666666666667, 'ndcg@10': 0.00013612986016388218}
# Metrics @ 20 for model combine (alpha=0.0): {'precision@20': 6.666666666666667e-05, 'recall@20': 0.0002666666666666667, 'ndcg@20': 0.00013612986016388218}
# Metrics @ 10 for model combine (alpha=0.1): {'precision@10': 0.00013333333333333334, 'recall@10': 0.0002666666666666667, 'ndcg@10': 0.00013612986016388218}
# Metrics @ 20 for model combine (alpha=0.1): {'precision@20': 6.666666666666667e-05, 'recall@20': 0.0002666666666666667, 'ndcg@20': 0.00013612986016388218}
# Metrics @ 10 for model combine (alpha=0.2): {'precision@10': 0.00013333333333333334, 'recall@10': 0.0002666666666666667, 'ndcg@10': 0.00013612986016388218}
# Metrics @ 20 for model combine (alpha=0.2): {'precision@20': 6.666666666666667e-05, 'recall@20': 0.0002666666666666667, 'ndcg@20': 0.00013612986016388218}
# Metrics @ 10 for model combine (alpha=0.30000000000000004): {'precision@10': 0.00013333333333333334, 'recall@10': 0.0002666666666666667, 'ndcg@10': 0.00013612986016388218}
# Metrics @ 20 for model combine (alpha=0.30000000000000004): {'precision@20': 0.00013333333333333334, 'recall@20': 0.0007111111111111111, 'ndcg@20': 0.00029255610217146765}
# Metrics @ 10 for model combine (alpha=0.4): {'precision@10': 0.00013333333333333334, 'recall@10': 0.0002666666666666667, 'ndcg@10': 0.00014265750982301838}
# Metrics @ 20 for model combine (alpha=0.4): {'precision@20': 0.00013333333333333334, 'recall@20': 0.0007111111111111111, 'ndcg@20': 0.00029908375183060386}
# Metrics @ 10 for model combine (alpha=0.5): {'precision@10': 0.00013333333333333334, 'recall@10': 0.0002666666666666667, 'ndcg@10': 0.00014265750982301838}
# Metrics @ 20 for model combine (alpha=0.5): {'precision@20': 0.00013333333333333334, 'recall@20': 0.0007111111111111111, 'ndcg@20': 0.00029908375183060386}
# Metrics @ 10 for model combine (alpha=0.6000000000000001): {'precision@10': 0.00013333333333333334, 'recall@10': 0.0002666666666666667, 'ndcg@10': 0.00014265750982301838}
# Metrics @ 20 for model combine (alpha=0.6000000000000001): {'precision@20': 0.00013333333333333334, 'recall@20': 0.0007111111111111111, 'ndcg@20': 0.000317193496713948}
# Metrics @ 10 for model combine (alpha=0.7000000000000001): {'precision@10': 0.0002666666666666667, 'recall@10': 0.0007111111111111111, 'ndcg@10': 0.00032352680773294876}
# Metrics @ 20 for model combine (alpha=0.7000000000000001): {'precision@20': 0.00013333333333333334, 'recall@20': 0.0007111111111111111, 'ndcg@20': 0.00032352680773294876}
# Metrics @ 10 for model combine (alpha=0.8): {'precision@10': 0.0002666666666666667, 'recall@10': 0.0007111111111111111, 'ndcg@10': 0.0003400454504669285}
# Metrics @ 20 for model combine (alpha=0.8): {'precision@20': 0.00013333333333333334, 'recall@20': 0.0007111111111111111, 'ndcg@20': 0.0003400454504669285}
# Metrics @ 10 for model combine (alpha=0.9): {'precision@10': 0.00013333333333333334, 'recall@10': 0.0002666666666666667, 'ndcg@10': 0.00014265750982301838}
# Metrics @ 20 for model combine (alpha=0.9): {'precision@20': 0.00013333333333333334, 'recall@20': 0.0007111111111111111, 'ndcg@20': 0.000317193496713948}
# Metrics @ 10 for model combine (alpha=1.0): {'precision@10': 0.00013333333333333334, 'recall@10': 0.0002666666666666667, 'ndcg@10': 0.00015073786901049607}
# Metrics @ 20 for model combine (alpha=1.0): {'precision@20': 0.00020000000000000004, 'recall@20': 0.0020444444444444442, 'ndcg@20': 0.0006460279476113222}

# %% [markdown]
# ### YELP Reviews

# %%
from datasets import load_dataset, load_from_disk

dataset_name = "yelp_reviews"
try:
  products = load_from_disk(dataset_name)
except:
  products = load_dataset("yashraizada/yelp-open-dataset-reviews", trust_remote_code=True)
  products.save_to_disk(dataset_name)
  products.cleanup_cache_files()

  print(products)

# %%
from loader import Loader
from utils import run_experiments

loader_yelp = Loader(dataset_name="yelp_reviews", subset_name="train", number_of_samples=NUM_SAMPLES, reviews_column="stars", asin_column="business_id", user_id_column="user_id")
results_yelp =run_experiments(loader_yelp, config, gamma, alpha, k_values)
sensitivity_yelp = sensitivity_analysis_combine(loader_yelp, config, gamma, k_values)
# Out:
# Metrics @ 10 for model pipeline (normalization=RLAE): {'precision@10': 0.0, 'recall@10': 0.0, 'ndcg@10': 0.0}
# Metrics @ 20 for model pipeline (normalization=RLAE): {'precision@20': 0.00013623978201634878, 'recall@20': 0.0027247956403269754, 'ndcg@20': 0.0006414411808355265}
# Metrics @ 10 for model combine (normalization=EASE): {'precision@10': 0.0, 'recall@10': 0.0, 'ndcg@10': 0.0}
# Metrics @ 20 for model combine (normalization=EASE): {'precision@20': 0.0, 'recall@20': 0.0, 'ndcg@20': 0.0}
# Metrics @ 10 for model regularization (normalization=LAE): {'precision@10': 0.005994550408719347, 'recall@10': 0.05994550408719346, 'ndcg@10': 0.030331947278049512}
# Metrics @ 20 for model regularization (normalization=LAE): {'precision@20': 0.0035422343324250684, 'recall@20': 0.07084468664850137, 'ndcg@20': 0.03310288557003581}
# Metrics @ 10 for model dan (normalization=RLAE): {'precision@10': 0.0, 'recall@10': 0.0, 'ndcg@10': 0.0}
# Metrics @ 20 for model dan (normalization=RLAE): {'precision@20': 0.0, 'recall@20': 0.0, 'ndcg@20': 0.0}
# Metrics @ 10 for model sapling (normalization=None): {'precision@10': 0.0035422343324250684, 'recall@10': 0.035422343324250684, 'ndcg@10': 0.017694323450469344}
# Metrics @ 20 for model sapling (normalization=None): {'precision@20': 0.0038147138964577656, 'recall@20': 0.07629427792915532, 'ndcg@20': 0.027860352946125832}
# Metrics @ 10 for model dan (normalization=EASE): {'precision@10': 0.0, 'recall@10': 0.0, 'ndcg@10': 0.0}
# Metrics @ 20 for model dan (normalization=EASE): {'precision@20': 0.0, 'recall@20': 0.0, 'ndcg@20': 0.0}
# Metrics @ 10 for model combine (alpha=0.0): {'precision@10': 0.0, 'recall@10': 0.0, 'ndcg@10': 0.0}
# Metrics @ 20 for model combine (alpha=0.0): {'precision@20': 0.0, 'recall@20': 0.0, 'ndcg@20': 0.0}
# Metrics @ 10 for model combine (alpha=0.1): {'precision@10': 0.0, 'recall@10': 0.0, 'ndcg@10': 0.0}
# Metrics @ 20 for model combine (alpha=0.1): {'precision@20': 0.0, 'recall@20': 0.0, 'ndcg@20': 0.0}
# Metrics @ 10 for model combine (alpha=0.2): {'precision@10': 0.0, 'recall@10': 0.0, 'ndcg@10': 0.0}
# Metrics @ 20 for model combine (alpha=0.2): {'precision@20': 0.0, 'recall@20': 0.0, 'ndcg@20': 0.0}
# Metrics @ 10 for model combine (alpha=0.30000000000000004): {'precision@10': 0.0, 'recall@10': 0.0, 'ndcg@10': 0.0}
# Metrics @ 20 for model combine (alpha=0.30000000000000004): {'precision@20': 0.0, 'recall@20': 0.0, 'ndcg@20': 0.0}
# Metrics @ 10 for model combine (alpha=0.4): {'precision@10': 0.0, 'recall@10': 0.0, 'ndcg@10': 0.0}
# Metrics @ 20 for model combine (alpha=0.4): {'precision@20': 0.0, 'recall@20': 0.0, 'ndcg@20': 0.0}
# Metrics @ 10 for model combine (alpha=0.5): {'precision@10': 0.0, 'recall@10': 0.0, 'ndcg@10': 0.0}
# Metrics @ 20 for model combine (alpha=0.5): {'precision@20': 0.0, 'recall@20': 0.0, 'ndcg@20': 0.0}
# Metrics @ 10 for model combine (alpha=0.6000000000000001): {'precision@10': 0.0, 'recall@10': 0.0, 'ndcg@10': 0.0}
# Metrics @ 20 for model combine (alpha=0.6000000000000001): {'precision@20': 0.0, 'recall@20': 0.0, 'ndcg@20': 0.0}
# Metrics @ 10 for model combine (alpha=0.7000000000000001): {'precision@10': 0.0, 'recall@10': 0.0, 'ndcg@10': 0.0}
# Metrics @ 20 for model combine (alpha=0.7000000000000001): {'precision@20': 0.0, 'recall@20': 0.0, 'ndcg@20': 0.0}
# Metrics @ 10 for model combine (alpha=0.8): {'precision@10': 0.0, 'recall@10': 0.0, 'ndcg@10': 0.0}
# Metrics @ 20 for model combine (alpha=0.8): {'precision@20': 0.0, 'recall@20': 0.0, 'ndcg@20': 0.0}
# Metrics @ 10 for model combine (alpha=0.9): {'precision@10': 0.0, 'recall@10': 0.0, 'ndcg@10': 0.0}
# Metrics @ 20 for model combine (alpha=0.9): {'precision@20': 0.0, 'recall@20': 0.0, 'ndcg@20': 0.0}
# Metrics @ 10 for model combine (alpha=1.0): {'precision@10': 0.0, 'recall@10': 0.0, 'ndcg@10': 0.0}
# Metrics @ 20 for model combine (alpha=1.0): {'precision@20': 0.0, 'recall@20': 0.0, 'ndcg@20': 0.0}

# %% [markdown]
# ## Metrics Plot

# %%
import pandas as pd
try:
    results_df = pd.DataFrame(results_yelp + results_products + results_books)
except NameError:
    results_df = pd.read_csv("results_lae.csv")
print(results_df)
results_df.to_csv("results_lae.csv", index=False)
# Out:
#                  dataset           model normalization   k  precision  \
# 0           yelp_reviews        pipeline          RLAE  10   0.000000
# 1           yelp_reviews        pipeline          RLAE  20   0.000136
# 2           yelp_reviews         combine          EASE  10   0.000000
# 3           yelp_reviews         combine          EASE  20   0.000000
# 4           yelp_reviews  regularization           LAE  10   0.005995
# 5           yelp_reviews  regularization           LAE  20   0.003542
# 6           yelp_reviews             dan          RLAE  10   0.000000
# 7           yelp_reviews             dan          RLAE  20   0.000000
# 8           yelp_reviews         sapling          None  10   0.003542
# 9           yelp_reviews         sapling          None  20   0.003815
# 10          yelp_reviews             dan          EASE  10   0.000000
# 11          yelp_reviews             dan          EASE  20   0.000000
# 12       amazon_products        pipeline           LAE  10   0.000000
# 13       amazon_products        pipeline           LAE  20   0.000067
# 14       amazon_products         combine           LAE  10   0.000133
# 15       amazon_products         combine           LAE  20   0.000133
# 16       amazon_products  regularization           LAE  10   0.000000
# 17       amazon_products  regularization           LAE  20   0.000200
# 18       amazon_products             dan           LAE  10   0.000133
# 19       amazon_products             dan           LAE  20   0.000067
# 20       amazon_products         sapling          None  10   0.001867
# 21       amazon_products         sapling          None  20   0.001267
# 22       amazon_products             dan           LAE  10   0.000133
# 23       amazon_products             dan           LAE  20   0.000067
# 24  amazon_reviews_books        pipeline           LAE  10   0.000000
# 25  amazon_reviews_books        pipeline           LAE  20   0.000500
# 26  amazon_reviews_books         combine           LAE  10   0.000000
# 27  amazon_reviews_books         combine           LAE  20   0.000000
# 28  amazon_reviews_books  regularization           LAE  10   0.000000
# 29  amazon_reviews_books  regularization           LAE  20   0.000333
# 30  amazon_reviews_books             dan           LAE  10   0.000667
# 31  amazon_reviews_books             dan           LAE  20   0.000333
# 32  amazon_reviews_books         sapling          None  10   0.000333
# 33  amazon_reviews_books         sapling          None  20   0.000333
# 34  amazon_reviews_books             dan           LAE  10   0.000667
# 35  amazon_reviews_books             dan           LAE  20   0.000333
#
#       recall      ndcg
# 0   0.000000  0.000000
# 1   0.002725  0.000641
# 2   0.000000  0.000000
# 3   0.000000  0.000000
# 4   0.059946  0.030332
# 5   0.070845  0.033103
# 6   0.000000  0.000000
# 7   0.000000  0.000000
# 8   0.035422  0.017694
# 9   0.076294  0.027860
# 10  0.000000  0.000000
# 11  0.000000  0.000000
# 12  0.000000  0.000000
# 13  0.001333  0.000314
# 14  0.000267  0.000143
# 15  0.000711  0.000299
# 16  0.000000  0.000000
# 17  0.002933  0.000812
# 18  0.000267  0.000136
# 19  0.000267  0.000136
# 20  0.016711  0.006662
# 21  0.023378  0.008294
# 22  0.000267  0.000136
# 23  0.000267  0.000136
# 24  0.000000  0.000000
# 25  0.002123  0.000795
# 26  0.000000  0.000000
# 27  0.000000  0.000000
# 28  0.000000  0.000000
# 29  0.003367  0.000945
# 30  0.000013  0.000694
# 31  0.000013  0.000448
# 32  0.003333  0.000964
# 33  0.003750  0.001185
# 34  0.000013  0.000694
# 35  0.000013  0.000448

# %%
# Plots - k=10
from utils import plot_grouped_bar

plot_grouped_bar(results_df, "precision", 10)
plot_grouped_bar(results_df, "recall", 10)
plot_grouped_bar(results_df, "ndcg", 10)

# %%
# Plots - k=20
plot_grouped_bar(results_df, "precision", 20)
plot_grouped_bar(results_df, "recall", 20)
plot_grouped_bar(results_df, "ndcg", 20)

# %% [markdown]
# ### Sensibilidad

# %%
import pandas as pd
try:
    sensitivity_df = pd.DataFrame(sensitivity_yelp + sensitivity_products + sensitivity_books)
except NameError:
    sensitivity_df = pd.read_csv("sensitivity.csv")
print(sensitivity_df)
sensitivity_df.to_csv("sensitivity.csv", index=False)
# Out:
#                  dataset    model normalization   k  alpha  precision  \
# 0           yelp_reviews  combine           LAE  10    0.0   0.000000
# 1           yelp_reviews  combine           LAE  20    0.0   0.000000
# 2           yelp_reviews  combine           LAE  10    0.1   0.000000
# 3           yelp_reviews  combine           LAE  20    0.1   0.000000
# 4           yelp_reviews  combine           LAE  10    0.2   0.000000
# ..                   ...      ...           ...  ..    ...        ...
# 61  amazon_reviews_books  combine           LAE  20    0.8   0.000000
# 62  amazon_reviews_books  combine           LAE  10    0.9   0.000000
# 63  amazon_reviews_books  combine           LAE  20    0.9   0.000000
# 64  amazon_reviews_books  combine           LAE  10    1.0   0.000333
# 65  amazon_reviews_books  combine           LAE  20    1.0   0.000167
#
#       recall      ndcg
# 0   0.000000  0.000000
# 1   0.000000  0.000000
# 2   0.000000  0.000000
# 3   0.000000  0.000000
# 4   0.000000  0.000000
# ..       ...       ...
# 61  0.000000  0.000000
# 62  0.000000  0.000000
# 63  0.000000  0.000000
# 64  0.000057  0.000261
# 65  0.000057  0.000169
#
# [66 rows x 8 columns]
